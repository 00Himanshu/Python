# %%
import random
ran=random.random()
print(ran)
print(15+ran*5)
# Out:
# 0.12794875052443988
# 15.639743752622199

# %%
def convertbioct(num,base=2):
  str1=""
  while num!=0:
    str1=str1+str(num%base)
    num=num//base
  str1=str1[::-1]
  print(str1)

num=int(input("Enter any number: "))
base=int(input("Enter the base: "))
convertbioct(num)
convertbioct(num, base)
# Out:
# Enter any number: 161
# Enter the base: 8
# 10100001
# 241

# %%
def fact(num):
  if num==1:
    return 1
  else:
    return num *fact(num-1)
n=int(input("Enter any number: "))
print(f"Factorial of {n} is {fact(n)}")
# Out:
# Enter any number: 4
# Factorial of 4 is 24
